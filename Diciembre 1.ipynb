# %% [markdown]
# # Interpolacion Cuadratica

# %%
import math
import numpy as np
import pylab as pl
valoresx1 = []
valoresy1 = []
valoresx = []
valoresy = []
valoresx2=[]
valoresy2=[]

def fx1(x):
        return math.exp(x)
def fix(x0,x1,x2,x):
    return (fx1(x0))+(((fx1(x1)-fx1(x0))/(x1-x0))*(x-x0))+(((((fx1(x2)-fx1(x1))/(x2-x1))-((fx1(x1)-fx1(x0))/(x1-x0)))/(x2-x0))*(x-x0))*(x-x1)
aux=1
while (aux<=6):
    y1=fx1(aux)
    valoresx1.append(aux)
    valoresy1.append(y1)
    auxiliar=aux
    while(auxiliar<=aux+1):
        y=fix(2,(4),(5),3)
        valoresx.append(auxiliar)
        valoresy.append(y)
        auxiliar+=0.1
        print y
    aux+=1
    
aux=1  
while (aux<=6):
    y1=fx1(aux)
    valoresx2.append(aux)
    valoresy2.append(y1)
    auxiliar=aux
    aux+=0.00001


f1=  pl.plot(valoresx1,valoresy1, '.')
f2=  pl.plot(valoresx,valoresy,"r")
f3=  pl.plot(valoresx2,valoresy2, "g")


pl.title("Interpolacion Cuadratica")
pl.xlabel("x")
pl.ylabel("y")
f=["puntos f(x)","Interpolacion cuadratica","Real"]
pl.legend(f,loc=4)
pl.xlim(0, 7)
pl.ylim(0, 2.5)
pl.grid(True)

pl.show()
# Out:
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986
# 7.5901156986

# %% [markdown]
# # interpolacion Lineal

# %%
import math
import numpy as np
import pylab as pl
valoresx1 = []
valoresy1 = []
valoresx = []
valoresy = []
valoresx2=[]
valoresy2=[]

def fx1(x):
        return math.log(x)
def fix(x0,x1,x):
    return (fx1(x0))+((fx1(x1)-fx1(x0))/(x1-x0))*(x-x0)
aux=1
while (aux<=6):
    y1=fx1(aux)
    valoresx1.append(aux)
    valoresy1.append(y1)
    auxiliar=aux
    while(auxiliar<=aux):
        y=fix(aux,(aux+1),auxiliar)
        valoresx.append(auxiliar)
        valoresy.append(y)
        auxiliar+=0.1
    aux+=1
    
aux=1  
while (aux<=6):
    y1=fx1(aux)
    valoresx2.append(aux)
    valoresy2.append(y1)
    auxiliar=aux
    aux+=0.00001


f1=  pl.plot(valoresx1,valoresy1, '.')
f2=  pl.plot(valoresx,valoresy,"r")
f3=  pl.plot(valoresx2,valoresy2, "g")


pl.title("Interpolacion Lineal")
pl.xlabel("x")
pl.ylabel("y")
f=["puntos f(x)","Interpolacion Lineal","Real"]
pl.legend(f,loc=4)
pl.xlim(0, 7)
pl.ylim(0, 2.5)
pl.grid(True)

pl.show()
# Out:
# 75.5657204655
# 75.5657204655

# %% [markdown]
# # Interpolacion de Newton

# %%
import math
import numpy as np
import pylab as pl
valoresx1 = []
valoresy1 = []
valoresx = []
valoresy = []
valoresx2=[]
valoresy2=[]

def fx1(x):
        return math.log(x)
def fix(x0,x1,x2,x):
    return (fx1(x0))+(((fx1(x1)-fx1(x0))/(x1-x0))*(x-x0))+(((((fx1(x2)-fx1(x1))/(x2-x1))-((fx1(x1)-fx1(x0))/(x1-x0)))/(x2-x0))*(x-x0))*(x-x1)

def fdf(xaux):
    if 

aux=1
while (aux<=6):
    y1=fx1(aux)
    valoresx1.append(aux)
    valoresy1.append(y1)
    auxiliar=aux
    while(auxiliar<=aux+1):
        y=fix(aux,(aux+1),(aux+2),auxiliar)
        valoresx.append(auxiliar)
        valoresy.append(y)
        auxiliar+=0.1
    aux+=1
    
aux=1  
while (aux<=6):
    y1=fx1(aux)
    valoresx2.append(aux)
    valoresy2.append(y1)
    auxiliar=aux
    aux+=0.00001


f1=  pl.plot(valoresx1,valoresy1, '.')
f2=  pl.plot(valoresx,valoresy,"r")
f3=  pl.plot(valoresx2,valoresy2, "g")


pl.title("Interpolacion de Newton")
pl.xlabel("x")
pl.ylabel("y")
f=["puntos f(x)","Interpolacion de Newton","Real"]
pl.legend(f,loc=4)
pl.xlim(0, 7)
pl.ylim(0, 2.5)
pl.grid(True)

pl.show()
# Out:
#   File "<ipython-input-3-3c68c3bc13bd>", line 17
#     if
#        ^
# SyntaxError: invalid syntax
